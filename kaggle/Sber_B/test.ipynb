# %%
import pandas as pd
import tqdm
import os
import re
import lightgbm as lgbm
import scipy
import numpy as np
import pickle

# %%
DATA_FILE = '../test.csv'
PREDICTION_FILE = '../pred.csv'

# %%
def normalize_answer(text):
    """Lower text and remove punctuation and extra whitespace."""
    return ' '.join(re.findall(r"\w+", text)).lower()


def sentence_to_word(sentences):
    sentences_in_words = list()
    for sentence in sentences:
        sentences_in_words.append(normalize_answer(sentence).split())
    return sentences_in_words


def text_to_sentence(text):
    sentences = text.split(".")
    return [s.strip() for s in sentences if s.strip() != '']


def get_max_match_sentance(data_row):
    sentences = text_to_sentence(data_row["paragraph"])
    sentences_in_words = sentence_to_word(sentences)
    question_in_words = sentence_to_word([data_row["question"]])[0]

    max_overlap = None
    max_match_sentance_id = None

    question_words = set(question_in_words)
    list_over = None
    for sentance_id in range(len(sentences_in_words)):
        sentence_words = set(sentences_in_words[sentance_id])
        overlap = len(sentence_words.intersection(question_words))
        if max_overlap is None or overlap > max_overlap:
            max_overlap = overlap
            max_match_sentance_id = sentance_id
            list_over = sentence_words.intersection(question_words)
    part_sent = set(sentences_in_words[max_match_sentance_id]).difference(list_over)



    return sentences[max_match_sentance_id], part_sent

# %%
X_test = pd.read_csv(DATA_FILE)

# %%
X_test['paragraph'] = X_test['paragraph'].apply(lambda x: str(x))
X_test['question'] = X_test['question'].apply(lambda x: str(x))

# %%
X_test['t_pred'] = 0
for data_ind in tqdm.tqdm(X_test.index.values):
    full_sentance, part_sentance = get_max_match_sentance(X_test.loc[data_ind])
    s = ''
    for i in part_sentance:
        s += i+' '
    X_test.loc[data_ind, 't_pred'] = s[:-1]
    X_test.loc[data_ind, 'full_t_pred'] = full_sentance
X_test['full_t_pred'] = X_test['full_t_pred'].apply(lambda x: str(x))
# Out:
# 100%|██████████| 40000/40000 [02:43<00:00, 245.10it/s]

# %%
X_test['paragraph_len_ch'] = X_test['paragraph'].apply(lambda x: len(x))
X_test['question_len_ch'] = X_test['question'].apply(lambda x: len(x))

X_test['paragraph'] = X_test['paragraph'].apply(lambda x: x.lower().split())
X_test['question'] = X_test['question'].apply(lambda x: x.lower().split())

X_test['paragraph_len'] = X_test['paragraph'].apply(lambda x: len(x))
X_test['question_len'] = X_test['question'].apply(lambda x: len(x))

tmp = pd.DataFrame(X_test.groupby('paragraph_id')['question_id'].count())
tmp.reset_index(inplace=True)
tmp.columns = ['paragraph_id', 'paragraph_freq']
X_test = pd.merge(X_test, tmp, on=['paragraph_id'], how='left')

# %%
rows = []
tmp = X_test.apply(lambda row: [rows.append([row['paragraph_id'], row['question_id'], nn]) 
                         for nn in row.paragraph], axis=1)

# %%
tmp = pd.DataFrame(rows)
tmp.columns = ['paragraph_id', 'question_id', 'word']
X_test = pd.merge(tmp, X_test, on=['paragraph_id', 'question_id'], how='left')

# %%
def f(x, y):    
    return x in y

# %%
X_test['in_t_pred'] = X_test.apply(lambda x: f(x['word'], x['t_pred']), axis=1)
X_test['in_full_t_pred'] = X_test.apply(lambda x: f(x['word'], x['full_t_pred']), axis=1)

# %%
X_paragraph_id = X_test['paragraph_id']
X_question_id = X_test['question_id']
word  = X_test['word']

del X_test['paragraph_id']
del X_test['question_id']
del X_test['word']
del X_test['paragraph']
del X_test['question']
del X_test['t_pred']
del X_test['full_t_pred']

# %%
X_test[:4]
# Out:
#    paragraph_len_ch  question_len_ch  paragraph_len  question_len  \
# 0               552               64             82             8
# 1               552               64             82             8
# 2               552               64             82             8
# 3               552               64             82             8
#
#    paragraph_freq  in_t_pred  in_full_t_pred
# 0               5      False           False
# 1               5      False            True
# 2               5      False            True
# 3               5      False            True

# %%
with open('lgb.pickle', 'rb') as f:
    lgb = pickle.load(f)

# %%
pred_test = lgb.predict_proba(X_test)[:,1]

# %%
tmp = pd.DataFrame(pred_test > 0.1)
tmp.columns = ['bool_pred']
tmp['pred'] = pd.DataFrame(pred_test)
tmp['paragraph_id'] = X_paragraph_id
tmp['question_id'] = X_question_id

# %%
tmp['word'] = word + ' '

result = pd.DataFrame(tmp[tmp.bool_pred == True].groupby(['paragraph_id', 'question_id'])['word'].apply(lambda x: x.sum()))
result.reset_index(inplace=True)
result.columns = ['paragraph_id', 'question_id', 'answer']

# %%
result.to_csv(PREDICTION_FILE, header=True, index=False)

# %%
pd.read_csv(PREDICTION_FILE)
# Out:
#        paragraph_id  question_id  \
# 0                 4        38010
# 1                 4        39058
# 2                 4        46148
# 3                 4        54480
# 4                 6         7569
# 5                 6        33361
# 6                 6        40187
# 7                 6        46399
# 8                 6        69892
# 9                 9        21639
# 10                9        51498
# 11                9        60121
# 12                9        65289
# 13                9        81944
# 14               10        16267
# 15               10        25631
# 16               10        40848
# 17               10        49613
# 18               12        21069
# 19               12        70651
# 20               12        70970
# 21               13        47059
# 22               13        54975
# 23               13        63374
# 24               13        70567
# 25               16         4237
# 26               16        73897
# 27               17        29263
# 28               17        40810
# 29               17        51009
# ...             ...          ...
# 39071         15116        46957
# 39072         15118        20198
# 39073         15118        28674
# 39074         15118        33077
# 39075         15118        65960
# 39076         15119        13550
# 39077         15119        23235
# 39078         15119        63005
# 39079         15119        67737
# 39080         15119        84428
# 39081         15120        10378
# 39082         15120        18579
# 39083         15120        20356
# 39084         15120        66740
# 39085         15122        25440
# 39086         15122        35708
# 39087         15122        39406
# 39088         15122        80500
# 39089         15124        23876
# 39090         15124        27430
# 39091         15124        28799
# 39092         15124        30849
# 39093         15124        83900
# 39094         15126        17692
# 39095         15126        21234
# 39096         15126        72488
# 39097         15126        75687
# 39098         15127        16783
# 39099         15127        16977
# 39100         15127        20952
#
#                                                   answer
# 0      и в и в и в в и в в и для манитобы характерен ...
# 1      по данным министерства окружающей среды и экол...
# 2      по данным министерства окружающей среды и экол...
# 3      по и манитоба занимает первое место по количес...
# 4      по прибытии в италию увлёкся жанровой живопись...
# 5      в и с и стал работой в этом жанре стала италья...
# 6      в и с и в в и а опх и ни ни опх с в в 1829 год...
# 7      прибытии в увлёкся жанровой живописью и наряду...
# 8      по в и с на и на эту в увидев её в современник...
# 9                          в в 19 азербайджанский и и и
# 10     осуществляемая в городе культурная политика пр...
# 11     в прежде из сложившегося жизненного уклада в и...
# 12     в в и их и и их предоставлен дом дружбы народо...
# 13     в прежде из сложившегося жизненного уклада пол...
# 14     в к как так и крови как так и в в и в в а рект...
# 15     в к с с и крови и выше но при этом в в осмотич...
# 16     в водной среде приводит к ряду проблем с осмор...
# 17     в к с с так и рыб так и но в организме солей в...
# 18     на в в в у со счётом с и со счётом 3:2 и ещё в...
# 19     на в в в у счётом далее последовала с испанией...
# 20     на в в в у со счётом далее последовала ничья с...
# 21                                           раз четыре
# 22     и в и в в исполнительные власти проводят свои ...
# 23     conseil является исполнительной властью и функ...
# 24     conseil administratif) является исполнительной...
# 25     умино うみのイルカ умино преподаватель академии выде...
# 26     ирука умино うみのイルカ умино преподаватель академи...
# 27     на чемпионат и на на на с и и с однако уже на ...
# 28     на чемпионат вышла в и на на групповом этапе к...
# 29                  в с в со с этого рой ходжсон ушел в
# ...                                                  ...
# 39071  с и и от в различий социальных отношений на из...
# 39072  с традиционно они группируются по типам исслед...
# 39073  с традиционно они группируются по типам исслед...
# 39074  с по изучает — — области внутри биологии далее...
# 39075  с по области внутри биологии далее делятся либ...
# 39076                                              1499
# 39077  в жуан фернандиш лаврадор ди в и в в в и и в в...
# 39078                 с и и и эти на планисфере кантино
# 39079  в 1499 с в и в примерно в то же самое в и и в ...
# 39080                в 1499 году лаврадор в в в в в в в
# 39081  в и и согласно официальным в было ранено свыше...
# 39082  в и человек и к согласно официальным данным, в...
# 39083  в и и к во в органами госбезопасности ссср был...
# 39084  в и и к во в органами госбезопасности ссср в и...
# 39085  стал в в в в в и с конца xvi века в порт стали...
# 39086  в в году отплыл французскую колонию в в 1564 г...
# 39087  в в в в в и с в с и контратаки королевской арм...
# 39088  в в 1555 отсюда основавший французскую колонию...
# 39089  в в не в от и в а в и в королевское распоряжен...
# 39090  в платину в в и топить в а ту в всенародно и т...
# 39091                                 от от 3 до 7 тонн
# 39092                                          1735 3 7
# 39093  в испанский король издаёт повелевающий впредь ...
# 39094                с в по у сферу неподвижных не не в
# 39095  с все орбиты в ней ним так что эпициклы сохран...
# 39096  с в ней движение по ним так что эпициклы сохра...
# 39097  эти полностью господствовавшей на тот момент г...
# 39098  с 2 по в 2017 году теплоход впервые поднялся в...
# 39099                                           конца а
# 39100           с конца работают 2 теплохода теплоход а
#
# [39101 rows x 3 columns]
